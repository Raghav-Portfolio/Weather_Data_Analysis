# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\1000490\Desktop\Jupyter_Implementation\wines.csv')
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'name', 'points', 'price',
#        'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
counter=0
for i in df['points']:
    if i==100:
        counter+=1
print(counter)

# make it more concise:
# len(df.loc[df['points']==100])
# Out:
# 19

# %%
df.loc[df['price'] == df['price'].max()]['name'].squeeze()
# Out:
# 'Glamorosa Sensible'

# %%
df['points_n']=df['points'] / 20
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.loc[df['price']<100]['price'].hist()
# Out:
# <Axes: >

# %%
x = df['price']
y = df['points']

# Create the scatter plot
plt.scatter(x, y)

plt.show()

# %%
df =  pd.read_csv('',  skiprows = 20, parse_dates=["    DATES"]) 
#make sure that you match the exact column name from the dataframe

# %%
df.loc[df['   TG'] != 9999].min() / 10

# %%
df.loc[df['   TG'] != 9999].max() / 10

# %%
df.loc[df['   TG'] != 9999].mean() / 10

# %%
df.loc[df['   TG'] != 9999].hist()

# %%
#Grab one single cell through the .squeeze() method
df.loc[df['   DATE'] == "1860-01-05"]['   TG'].squeeze() / 10

# %%
df.loc(df['   TG']) == df['   TG'].max()['    DATE'].squeeze()
